# %%
# Function copy
def welcome():
    return "Welcome to advanced python course"

# %%
wel = welcome
print(wel())
del welcome
print(wel())
# Out:
# Welcome to advanced python course
# Welcome to advanced python course

# %%
# Closure-:
def main_welcome(msg):
    def sub_welcome_method():
        print(f"Welcome to advanced python course")
        print(msg)
        print("Please learne these concepts properly")
    return sub_welcome_method()

# %%
main_welcome("Welcome EveryOne")
# Out:
# Welcome to advanced python course
# Welcome EveryOne
# Please learne these concepts properly

# %%
def main_welcome(func):
    def sub_welcome_method():
        print(f"Welcome to advanced python course")
        func("Welcome everyone to this tutorial")
        print("Please learne these concepts properly")
    return sub_welcome_method()

# %%
main_welcome(print)
# Out:
# Welcome to advanced python course
# Welcome everyone to this tutorial
# Please learne these concepts properly

# %%
def main_welcome(func,lst):
    def sub_welcome_method():
        print(f"Welcome to advanced python course")
        print(func(lst))
        print("Please learn these concepts properly")
    return sub_welcome_method()

# %%
main_welcome(len,[1,2,3,4])
# Out:
# Welcome to advanced python course
# 4
# Please learn these concepts properly

# %%
# DECORATOR-:
def main_welcome(func):
    def sub_welcome_method():
        print(f"Welcome to advanced python course")
        func()
        print("Please learn these concepts properly")
    return sub_welcome_method()

# %%
def course_introduction():
    print("This is an advanced python course")

course_introduction()
# Out:
# This is an advanced python course

# %%
main_welcome(course_introduction)
# Out:
# Welcome to advanced python course
# This is an advanced python course
# Please learn these concepts properly

# %%
@main_welcome
def course_introduction():
    print("This is an advanced python course")
# Out:
# Welcome to advanced python course
# This is an advanced python course
# Please learn these concepts properly

# %%
# Decorator-:
def my_decorator(func):
    def wrapper():
        print("Something is happening before the function is called.")
        func()
        print("Something is happening after the function is called.")
    return wrapper

# %%
@my_decorator
def say_hello():
    print("Hello")
# say_hello = my_decorator(say_hello)

# %%
say_hello()
# Out:
# Something is happening before the function is called.
# Hello
# Something is happening after the function is called.

# %%
## Decorators With arguments
def repeat(n):
    def decorator(func):
        def wrapper(*args, **kwargs):
            for _ in range(n):
                func(*args, **kwargs)
        return wrapper
    return decorator

# %%
@repeat(3)
def say_hi():
    print("hi")

# %%
say_hi()
# Out:
# hi
# hi
# hi
