# %%
my_list = [1,2,3,4,5,6]
for i in my_list:
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %%
type(my_list)
# Out:
# list

# %%
print(my_list)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
my_list
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
# Iterators-:
iterator = iter(my_list)
print(type(iterator))
# Out:
# <class 'list_iterator'>

# %%
iterator

# %%
for i in iterator:
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %%
for i in iterator:
    print(i)

# %%
iterator = iter(my_list)

# %%
next(iterator)
# Out:
# 1

# %%
next(iterator)
# Out:
# 2

# %%
iterator = iter(my_list)

# %%
iterator

# %%
print(iterator)
# Out:
# <list_iterator object at 0x0000025DFA8CED70>

# %%
print(iterator)
# Out:
# <list_iterator object at 0x0000025DFA8CED70>

# %%
iterator = iter(my_list)

# %%
try:
    print(next(iterator))
except StopIteration:
    print("No elements left in the iterator")
# Out:
# No elements left in the iterator

# %%
next(iterator)
# Out:
# 2

# %%
my_string = "Hello"
string_iterator = iter(my_string)

# %%
# String iterator
# my_string = "Hello"
# string_iterator = iter(my_string)
print(type(string_iterator))
print(next(string_iterator))  # Output: H
print(next(string_iterator))  # Output: e
# Out:
# <class 'str_ascii_iterator'>
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[36], line 5
#       1 # String iterator
#       2 # my_string = "Hello"
#       3 # string_iterator = iter(my_string)
#       4 print(type(string_iterator))
# ----> 5 print(next(string_iterator))  # Output: H
#       6 print(next(string_iterator))  # Output: e
#
# StopIteration:
