# %%
import os
cwd = os.getcwd()
print(f"Current working directory: {cwd}")
# Out:
# Current working directory: c:\Users\Omkar Raut\Desktop\DataSceince\6-File_Handling

# %%
new_dir = "package"
os.mkdir("package")
print(f"Directory: '{new_dir} created successfully.")
# Out:
# Directory: 'package created successfully.

# %%
# Listing Files and Directories-:
items = os.listdir('.')
print(items)
# Out:
# ['6.1-fileOperation.ipynb', '6.2-filepath.ipynb', 'activity.log', 'copy_image.bin', 'data.csv', 'data.json', 'data.txt', 'destination.txt', 'dst.txt', 'example.bin', 'example.txt', 'filehandlingquestions.ipynb', 'filehandlingsolution.ipynb', 'image.bin', 'large.txt', 'log.txt', 'merged.txt', 'omkar.csv', 'output.txt', 'package', 'protected.txt', 'sample.txt', 'small0.txt', 'small1.txt', 'small2.txt', 'small3.txt', 'small4.txt', 'small5.txt', 'source.txt']

# %%
# joining path-:
dir_name = "folder"
file_name="file.txt"
full_path = os.path.join(os.getcwd(),dir_name, file_name)
print(full_path)
# Out:
# c:\Users\Omkar Raut\Desktop\DataSceince\6-File_Handling\folder\file.txt

# %%
path = "example1.txt"
if os.path.exists(path):
    print(f"The path: '{path}' exists")
else:
    print(f"The path: '{path}' does NOT exists")
# Out:
# The path: 'example1.txt' does NOT exists

# %%
# Checking if a Path is a File or Directory-:
import os

path = 'example.txt'
if os.path.isfile(path):
    print(f"The path '{path}' is a file.")
elif os.path.isdir(path):
    print(f"The path '{path}' is a directory.")
else:
    print(f"The path '{path}' is neither a file nor a directory")
# Out:
# The path 'example.txt' is a file.

# %%
relative_path = 'example.txt'
absolute_path = os.path.abspath(relative_path)
print(absolute_path)
# Out:
# c:\Users\Omkar Raut\Desktop\DataSceince\6-File_Handling\example.txt
