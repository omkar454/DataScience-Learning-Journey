# %% [markdown]
# # Module: Exception Handling Assignments
# ## Lesson: Exception Handling with try, except, and finally
# ### Assignment 1: Handling Division by Zero
#
# Write a function that takes two integers as input and returns their division. Use try, except, and finally blocks to handle division by zero and print an appropriate message.

# %%
def divide(a,b):
    try:
        result = a/b
    except ZeroDivisionError:
        result = None
        print("Cannot divide by Zero. b cannot be zero")
    finally:
        print("Function execution completed")
    return result

print(divide(2,0))
# Out:
# Cannot divide by Zero. b cannot be zero
# Function execution completed
# None

# %% [markdown]
# ### Assignment 2: File Reading with Exception Handling
#
# Write a function that reads the contents of a file named `data.txt`. Use try, except, and finally blocks to handle file not found errors and ensure the file is properly closed.

# %%
def file_reader(filePath):
    try:
        file = open(filePath,"r")
        content = file.read()
    except FileNotFoundError:
        content = None
        print("File does not exists at the given location")
    finally:
        if "file" in locals() and not file.closed:
            print(locals())
            file.close()
            print("File opened and closed successfully\n")
    return content

print(file_reader("example1.txt"))
# Out:
# {'filePath': 'example1.txt', 'file': <_io.TextIOWrapper name='example1.txt' mode='r' encoding='utf-8'>, 'content': 'This is the data science course\nPlease complete it before 5th jan'}
# File opened and closed successfully
#
# This is the data science course
# Please complete it before 5th jan

# %% [markdown]
# ### Assignment 3: Handling Multiple Exceptions
#
# Write a function that takes a list of integers and returns their sum. Use try, except, and finally blocks to handle TypeError if a non-integer value is encountered and print an appropriate message.

# %%
def sum_list(lst):
    try:
        for i in lst:
            if not isinstance(i,int):
                raise TypeError
        value = int(sum(lst))
    except TypeError:
        print("Please enter only integer values")
        value=None
    finally:
        print("Execution done")
    return value


print(sum_list([1,2,4,45,44.4]))
# Out:
# Please enter only integer values
# Execution done
# None

# %% [markdown]
# ### Assignment 4: Exception Handling in User Input
#
# Write a function that prompts the user to enter an integer. Use try, except, and finally blocks to handle ValueError if the user enters a non-integer value and print an appropriate message.

# %%
def int_prompt():
    try:
        entered_val = input("Enter an Integer")
        value = f"{int(entered_val)} is a valid integer"
    except ValueError:
        print(f"{entered_val} is not an integer. Please enter an integer only")
        value = None
    finally:
        print("Execution done")
    return value

print(int_prompt())
# Out:
# a is not an integer. Please enter an integer only
# Execution done
# None

# %% [markdown]
# ### Assignment 5: Exception Handling in Dictionary Access
#
# Write a function that takes a dictionary and a key as input and returns the value associated with the key. Use try, except, and finally blocks to handle KeyError if the key is not found in the dictionary and print an appropriate message.

# %%
def key_value_finder(dict,key):
    try:
        value = dict[key]
    except KeyError as e:
        value = None
        print("Key is not present in dictionary")
        print(f"hi:{e}")
    finally:
        print("Execution completed")
    return value

print(key_value_finder({"omkar":20,"raut":19},"omkkar"))
# Out:
# Key is not present in dictionary
# hi:'omkkar'
# Execution completed
# None
