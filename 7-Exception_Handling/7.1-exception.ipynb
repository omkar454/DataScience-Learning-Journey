# %%
a=b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 a=b
#
# NameError: name 'b' is not defined

# %%
# Exception try, except block-:
try:
    a=b
except NameError as Ne:
    print(Ne)
    print("Variable has NOT been assigned.")
# Out:
# name 'b' is not defined
# Variable has NOT been assigned.

# %%
result = 1/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 result = 1/0
#
# ZeroDivisionError: division by zero

# %%
try:
    result = 1/0
except ZeroDivisionError as ex:
    print(ex)
    print("Please enter the denominator greater than 0")
# Out:
# division by zero
# Please enter the denominator greater than 0

# %%
try:
    a=b
    result = 1/0
except ZeroDivisionError as ex:
    print(ex)
    print("Please enter the denominator greater than 0")
except Exception as ex1:
    print(ex1)
    print('Main exception got caught here')
# Out:
# name 'b' is not defined
# Main exception got caught here

# %%
try:
    num = int(input("Enter a number"))
    result = 10/num
except ValueError:
    print("This is not a valid number")
except ZeroDivisionError:
    print("Enter denominator greater than 0")
except Exception as ex:
    print(ex)
else:
    print(round(result,2))
    print("Execution completed successfully")
finally:
    print("Exception handling process completed")
# Out:
# 1.67
# Execution completed successfully
# Exception handling process completed

# %%
print(open('example1.txt','r'))
# Out:
# <_io.TextIOWrapper name='example1.txt' mode='r' encoding='utf-8'>

# %%
print(open('example1.txt','r').close())
# Out:
# None

# %%
try:
    file = open('example1.txt','r')
    content = file.read()
    a=b
    print(content)
except FileNotFoundError:
    print("The file does not exists")
except Exception as ex:
    print(ex)
finally:
    if 'file' in locals() and not file.closed:
        file.close()
        print("File closed successfully")
# Out:
# name 'b' is not defined
# File closed successfully

# %% [markdown]
# locals()-:
# Return a dictionary containing the current scope's local variables.

# %%
file in locals()
# Out:
# False

# %%
not file.closed
# Out:
# False

# %%
print(locals())
# Out:
# {'__name__': '__main__', '__doc__': 'Automatically created module for IPython interactive environment', '__package__': None, '__loader__': None, '__spec__': None, '__builtin__': <module 'builtins' (built-in)>, '__builtins__': <module 'builtins' (built-in)>, '_ih': ['', 'try:\n    a=b\n    result = 1/0\nexcept ZeroDivisionError as ex:\n    print(ex)\n    print("Please enter the denominator greater than 0")\nexcept Exception as ex1:\n    print(ex1)\n    print(\'Main exception got caught here\')', 'try:\n    num = int(input("Enter a number"))\n    result = 10/num\nexcept ValueError:\n    print("This is not a valid number")\nexcept ZeroDivisionError:\n    print("Enter denominator greater than 0")\nexcept Exception as ex:\n    print(ex)\nelse:\n    print(round(result,2))\n    print("Execution completed successfully")\nfinally:\n    print("Exception handling process completed")', 'try:\n    num = int(input("Enter a number"))\n    result = 10/num\nexcept ValueError:\n    print("This is not a valid number")\nexcept ZeroDivisionError:\n    print("Enter denominator greater than 0")\nexcept Exception as ex:\n    print(ex)\nelse:\n    print(round(result,2))\n    print("Execution completed successfully")\nfinally:\n    print("Exception handling process completed")', 'try:\n    file = open(\'example1.txt\',\'r\')\n    content = file.read()\n    a=b\n    print(content)\nexcept FileNotFoundError:\n    print("The file does not exists")\nexcept Exception as ex:\n    print(ex)\nfinally:\n    if \'file\' in locals() and not file.closed:\n        file.close()\n        print("File closed successfully")', 'print(locals())', 'file in locals()', 'not file.closed', 'print(locals())'], '_oh': {6: False, 7: False}, '_dh': [WindowsPath('c:/Users/Omkar Raut/Desktop/DataSceince/7-Exception_Handling')], 'In': ['', 'try:\n    a=b\n    result = 1/0\nexcept ZeroDivisionError as ex:\n    print(ex)\n    print("Please enter the denominator greater than 0")\nexcept Exception as ex1:\n    print(ex1)\n    print(\'Main exception got caught here\')', 'try:\n    num = int(input("Enter a number"))\n    result = 10/num\nexcept ValueError:\n    print("This is not a valid number")\nexcept ZeroDivisionError:\n    print("Enter denominator greater than 0")\nexcept Exception as ex:\n    print(ex)\nelse:\n    print(round(result,2))\n    print("Execution completed successfully")\nfinally:\n    print("Exception handling process completed")', 'try:\n    num = int(input("Enter a number"))\n    result = 10/num\nexcept ValueError:\n    print("This is not a valid number")\nexcept ZeroDivisionError:\n    print("Enter denominator greater than 0")\nexcept Exception as ex:\n    print(ex)\nelse:\n    print(round(result,2))\n    print("Execution completed successfully")\nfinally:\n    print("Exception handling process completed")', 'try:\n    file = open(\'example1.txt\',\'r\')\n    content = file.read()\n    a=b\n    print(content)\nexcept FileNotFoundError:\n    print("The file does not exists")\nexcept Exception as ex:\n    print(ex)\nfinally:\n    if \'file\' in locals() and not file.closed:\n        file.close()\n        print("File closed successfully")', 'print(locals())', 'file in locals()', 'not file.closed', 'print(locals())'], 'Out': {6: False, 7: False}, 'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x00000279D47B5D30>>, 'exit': <IPython.core.autocall.ZMQExitAutocall object at 0x00000279D5C3AA80>, 'quit': <IPython.core.autocall.ZMQExitAutocall object at 0x00000279D5C3AA80>, 'open': <function open at 0x00000279D39C5260>, '_': False, '__': False, '___': '', '__vsc_ipynb_file__': 'c:\\Users\\Omkar Raut\\Desktop\\DataSceince\\7-Exception_Handling\\7.1-exception.ipynb', '_i': 'not file.closed', '_ii': 'file in locals()', '_iii': 'print(locals())', '_i1': 'try:\n    a=b\n    result = 1/0\nexcept ZeroDivisionError as ex:\n    print(ex)\n    print("Please enter the denominator greater than 0")\nexcept Exception as ex1:\n    ...
