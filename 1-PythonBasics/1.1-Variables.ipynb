# %%
age = int(input("age "))
print(age)
print(type(age))
# Out:
# 23
# <class 'int'>

# %%
# Dynamic Typing
var = 10
a=20
print(var, type(var),a," hello")
# Out:
# 10 <class 'int'> 20  hello

# %%
3/2
# Out:
# 1.5

# %%
3//2
# Out:
# 1

# %%
age="-7"
int(age)
# Out:
# -7
