# %% [markdown]
# ### Python Example
# necessary to install ipykernel

# %%
1+1
# Out:
# 2

# %%
## Line Continuation-:
total = 1 +2 +3 +4 +5 +6 + \
7
print(total)
# Out:
# 28

# %%
# Multiple statements on a single line-:
x=5;y=10;z=x+y
print(z)
# Out:
# 15

# %%
age = 32
type(age)
# Out:
# int
