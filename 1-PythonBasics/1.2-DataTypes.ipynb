# %%
a=10
b=10
type(a==b)
# Out:
# bool

# %%
"hello" + 5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 "hello" + 5
#
# TypeError: can only concatenate str (not "int") to str

# %%
"hello" + str(5)
# Out:
# 'hello5'
