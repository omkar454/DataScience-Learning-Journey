# %%
class Car:
    def __init__(self, windows, doors, enginetype):
        self.windows = windows
        self.doors = doors
        self.enginetype = enginetype

    def drive(self):
        print(f"The person will drive the {self.enginetype} car")

# %%
car1 = Car(4,5,"petrol")
car1.drive()
# Out:
# The person will drive the petrol car

# %%
class Tesla(Car):
    def __init__(self, windows,doors,enginetype,is_selfDriving):
        super().__init__(windows,doors,enginetype)
        self.is_selfDriving = is_selfDriving

    def selfdriving(self):
        print(f"Tesla supports self driving: {self.is_selfDriving}")

# %%
tesla = Tesla(4,5,"electric",True)
tesla.selfdriving()
# Out:
# Tesla supports self driving: True

# %%
tesla.drive()
# Out:
# The person will drive the electric car

# %%
# Multiple Inheritance-:
# When a class inherits from more than one base class.

class Animal:
    def __init__(self, name):
        self.name = name

    def speak(self):
        print("SubClass must implement this method")


class Pet:
    def __init__(self, owner):
        self.owner = owner


class Dog(Animal, Pet):
    def __init__(self, name, owner):
        Animal.__init__(self,name)
        Pet.__init__(self,owner)

    def speak(self):
        return f"{self.name} says Woof"
    
# Create an object-:
dog = Dog("Buddy", "Krish")
print(dog.speak())
print(f"Owner: {dog.owner}")
# Out:
# Buddy says Woof
# Owner: Krish

# %%
"""
You write self when calling parent class directly because:

ClassName.method(self, …) does NOT automatically get self → you must pass it manually.

If you use super(), Python passes self automatically. and also with objName.method() "self" is passed automatically
"""
# Out:
# '\nYou write self when calling parent class directly because:\n\nClassName.method(self, …) does NOT automatically get self → you must pass it manually.\n\nIf you use super(), Python passes self automatically. and also with objName.method() "self" is passed automatically\n'
