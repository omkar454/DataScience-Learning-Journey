# %%
class Animal:
    def speak(self):
        return "Sound of animal"
    
# Derived Class 1-:
class Dog(Animal):
    def speak(self):
        return "Woof Woof!!"
    

# Derived Class 2-:
class Cat(Animal):
    def speak(self):
        return "Meow!"

def animal_speak(animal):
    print(animal.speak())

dog = Dog()
cat = Cat()
# print(dog.speak())
# print(cat.speak())

animal_speak(dog)
animal_speak(cat)
# Out:
# Woof Woof!!
# Meow!
# Woof Woof!!
# Meow!

# %%
# Polymorphism with Functions and Methods-:
import math
class Shape:
    def area(self):
        return "The area of the figure"
    
class Rectangle(Shape):
    def __init__(self,width, height):
        self.width = width
        self.height = height

    def area(self):
        return self.width * self.height
    
class Circle(Shape):
    def __init__(self,radius):
        self.radius = radius

    def area(self):
        return math.pi*self.radius**2

def print_area(shape):
    print(f"The area is: {round(shape.area(),2)}")

rectangle = Rectangle(3,4)
circle = Circle(4)

print_area(rectangle)
print_area(circle)
# Out:
# The area is: 12
# The area is: 50.27

# %%
# ABC -: Abstract Base Class
from abc import ABC,abstractmethod

class Vehicle(ABC):
    @abstractmethod
    def start_engine(self):
        pass

class Car(Vehicle):
    def start_engine(self):
        return "Car engine started"
    
class Motorcycle(Vehicle):
    def start_engine(self):
        return "MotorCycle engine started"
    
def start_Vehicle(vehicle):
    print(vehicle.start_engine())
    
car = Car()
motorcycle = Motorcycle()

start_Vehicle(car)
start_Vehicle(motorcycle)
# Out:
# Car engine started
# MotorCycle engine started

# %%
# If an inherited class does not implement the abstract method →
# 👉 Error will occur when creating object.
